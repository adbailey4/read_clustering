# %% [markdown]
# # Characterizing clusters found by kmeans

# %%
from read_clustering.variant_call import VariantCall
path = 'C:/Users/lalaj/PycharmProjects/untitled3/read_clustering/tests/test_files/native_cbf5_gal.csv'
native = VariantCall(path)
list_18 = native.get_contig_positions('RDN18-1')
list_25 = native.get_contig_positions('RDN25-1')

# %% [markdown]
# Each row in the plots below represents the average trends of modification in each of the clusters found by kmeans. The color code represents percentage of reads that have the indicated position modified. Dark red (with a value of 100) shows that in that cluster, 100% of the times that position is modified. Similarly, white shows that the position is never or almost never modified in that cluster.

# %%
native.positions_modification_plot_kmeans_clusters(list_18, max_number_clusters = 6, subunit_name = '18S')

# %%
native.positions_modification_plot_kmeans_clusters(list_25, max_number_clusters = 6, subunit_name = '25S')

# %% [markdown]
# The following are the density plots for each position found in 18S (as some positions in this contig show clear patterns). The x axis has the possible variant probabilities and the y axis the number of reads that have each of those probabilities.

# %%
native.clusters_for_position_pdf(list_18, list_18, max_number_clusters = 6)
